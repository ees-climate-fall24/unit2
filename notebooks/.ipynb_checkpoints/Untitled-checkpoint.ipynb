# %%
import matplotlib.pyplot as plt 
import xarray as xr
import cftime

# %%
SST_OISST = xr.open_dataset('/home/pachamama/shared/model_output/obs/oisst/sst.oisst.mon.ltm.1991-2020.nc',
                    use_cftime=True).drop(labels='time')

# %%
new_sst = SST_OISST.assign_coords({'time':times})

# %%
new_sst
# Out:
# <xarray.Dataset>
# Dimensions:             (lat: 180, lon: 360, time: 12, nbnds: 2)
# Coordinates:
#   * lat                 (lat) float32 -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#   * lon                 (lon) float32 0.0 1.0 2.0 3.0 ... 357.0 358.0 359.0
#   * time                (time) datetime64[ns] 1991-01-01 ... 1991-12-01
# Dimensions without coordinates: nbnds
# Data variables:
#     climatology_bounds  (time, nbnds) object ...
#     sst                 (time, lat, lon) float32 ...
#     valid_yr_count      (time, lat, lon) float32 ...
# Attributes: (12/13)
#     CDI:                            Climate Data Interface version 1.9.10 (ht...
#     source:                         NOAA/NCEI https://www.ncei.noaa.gov/data/...
#     institution:                    NOAA/National Centers for Environmental I...
#     Conventions:                    CF-1.5
#     title:                          NOAA/NCEI 1/4 Degree Daily Optimum Interp...
# ...

# %%
new_sst.to_netcdf('sst.oisst.mon.ltm.1991-2020.nc')

# %%
xr.open_dataset('sst.oisst.mon.ltm.1991-2020.nc')
# Out:
# <xarray.Dataset>
# Dimensions:             (lat: 180, lon: 360, time: 12, nbnds: 2)
# Coordinates:
#   * lat                 (lat) float32 -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#   * lon                 (lon) float32 0.0 1.0 2.0 3.0 ... 357.0 358.0 359.0
#   * time                (time) datetime64[ns] 1991-01-01 ... 1991-12-01
# Dimensions without coordinates: nbnds
# Data variables:
#     climatology_bounds  (time, nbnds) datetime64[ns] ...
#     sst                 (time, lat, lon) float32 ...
#     valid_yr_count      (time, lat, lon) float32 ...
# Attributes: (12/13)
#     CDI:                            Climate Data Interface version 1.9.10 (ht...
#     source:                         NOAA/NCEI https://www.ncei.noaa.gov/data/...
#     institution:                    NOAA/National Centers for Environmental I...
#     Conventions:                    CF-1.5
#     title:                          NOAA/NCEI 1/4 Degree Daily Optimum Interp...
# ...
